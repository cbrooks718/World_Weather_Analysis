# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_description = city_weather['weather'][0]['description']   
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | lae
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | sorong
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | saint-louis
# Processing Record 8 of Set 1 | marrakesh
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | aykhal
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | zlobin
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | lisakovsk
# Processing Record 17 of Set 1 | bonthe
# Processing Record 18 of Set 1 | rawson
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | sovetskiy
# Processing Record 21 of Set 1 | killybegs
# Processing Record 22 of Set 1 | lethem
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | sekoma
# Processing Record 25 of Set 1 | belawan
# Processing Record 26 of Set 1 | lorengau
# Processing Record 27 of Set 1 | tarko-sale
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | tatvan
# Processing Record 33 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 1 | san cristobal
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | magadan
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | eyrarbakki
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | mago
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | byron bay
# Processing Record 49 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | tooele
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | hecun
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | khandyga
# Processing Record 11 of Set 2 | hohhot
# Processing Record 12 of Set 2 | kudahuvadhoo
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | dudinka
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | lagoa
# Processing Record 17 of Set 2 | karratha
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | rio claro
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | borogontsy
# Processing Record 25 of Set 2 | kyakhta
# Processing Record 26 of Set 2 | valea crisului
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | bud
# Processing Record 29 of Set 2 | padang
# Processing Record 30 of Set 2 | constitucion
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | ostrovnoy
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | itacoatiara
# Processing Record 37 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 2 | vestmanna
# Processing Record 39 of Set 2 | russell
# Processing Record 40 of Set 2 | aksu
# Processing Record 41 of Set 2 | otane
# Processing Record 42 of Set 2 | la cruz
# Processing Record 43 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 2 | bartica
# Processing Record 45 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 2 | hualmay
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | turayf
# Processing Record 3 of Set 3 | bayangol
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | ahipara
# Processing Record 6 of Set 3 | kosh-agach
# Processing Record 7 of Set 3 | batemans bay
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | prince rupert
# Processing Record 10 of Set 3 | raga
# Processing Record 11 of Set 3 | quilmana
# Processing Record 12 of Set 3 | hinton
# Processing Record 13 of Set 3 | honningsvag
# Processing Record 14 of Set 3 | marawi
# Processing Record 15 of Set 3 | honiara
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 3 | yerbogachen
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | mahajanga
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | kyren
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | abu samrah
# Processing Record 26 of Set 3 | magdalena
# Processing Record 27 of Set 3 | batagay
# Processing Record 28 of Set 3 | huntington
# Processing Record 29 of Set 3 | lucapa
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | xuddur
# Processing Record 33 of Set 3 | patiya
# Processing Record 34 of Set 3 | jacksonville beach
# Processing Record 35 of Set 3 | carauari
# Processing Record 36 of Set 3 | naples
# Processing Record 37 of Set 3 | kumta
# Processing Record 38 of Set 3 | port said
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | mayo
# Processing Record 41 of Set 3 | vila velha
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | zhezkazgan
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | okha
# Processing Record 47 of Set 3 | bara
# Processing Record 48 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 49 of Set 3 | kindu
# Processing Record 50 of Set 3 | hofn
# Processing Record 1 of Set 4 | sitka
# Processing Record 2 of Set 4 | cap malheureux
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | mnogovershinnyy
# Processing Record 5 of Set 4 | lima
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | santiago de compostela
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | papar
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | chaman
# Processing Record 13 of Set 4 | kununurra
# Processing Record 14 of Set 4 | belaya gora
# Processing Record 15 of Set 4 | cape town
# Processing Record 16 of Set 4 | yuli
# Processing Record 17 of Set 4 | hami
# Processing Record 18 of Set 4 | bonavista
# Processing Record 19 of Set 4 | arlit
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | bilma
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | yulara
# Processing Record 24 of Set 4 | lata
# Processing Record 25 of Set 4 | great yarmouth
# Processing Record 26 of Set 4 | letka
# Processing Record 27 of Set 4 | urcos
# Processing Record 28 of Set 4 | seybaplaya
# Processing Record 29 of Set 4 | oistins
# Processing Record 30 of Set 4 | itaperucu
# Processing Record 31 of Set 4 | atambua
# Processing Record 32 of Set 4 | langsa
# Processing Record 33 of Set 4 | assiniboia
# Processing Record 34 of Set 4 | necochea
# Processing Record 35 of Set 4 | mwinilunga
# Processing Record 36 of Set 4 | jalu
# Processing Record 37 of Set 4 | aleksandrov gay
# Processing Record 38 of Set 4 | ambanja
# Processing Record 39 of Set 4 | new norfolk
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | santa rosa
# Processing Record 42 of Set 4 | aklavik
# Processing Record 43 of Set 4 | yeppoon
# Processing Record 44 of Set 4 | nuevitas
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | shenjiamen
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | pacific grove
# Processing Record 49 of Set 4 | samarai
# Processing Record 50 of Set 4 | mossendjo
# Processing Record 1 of Set 5 | kargil
# Processing Record 2 of Set 5 | qaqortoq
# Processing Record 3 of Set 5 | somerset
# Processing Record 4 of Set 5 | kodinsk
# Processing Record 5 of Set 5 | ribnitz-damgarten
# Processing Record 6 of Set 5 | luderitz
# Processing Record 7 of Set 5 | seoul
# Processing Record 8 of Set 5 | xai-xai
# Processing Record 9 of Set 5 | cabedelo
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | nyurba
# Processing Record 14 of Set 5 | borba
# Processing Record 15 of Set 5 | choix
# Processing Record 16 of Set 5 | jamestown
# Processing Record 17 of Set 5 | adrar
# Processing Record 18 of Set 5 | clyde river
# Processing Record 19 of Set 5 | dubbo
# Processing Record 20 of Set 5 | north bend
# Processing Record 21 of Set 5 | mandalgovi
# Processing Record 22 of Set 5 | belyy yar
# Processing Record 23 of Set 5 | baracoa
# Processing Record 24 of Set 5 | zyryanka
# Processing Record 25 of Set 5 | arua
# Processing Record 26 of Set 5 | nouadhibou
# Processing Record 27 of Set 5 | harper
# Processing Record 28 of Set 5 | margate
# Processing Record 29 of Set 5 | burnie
# Processing Record 30 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 5 | plettenberg bay
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | codrington
# Processing Record 34 of Set 5 | san vicente
# Processing Record 35 of Set 5 | olafsvik
# Processing Record 36 of Set 5 | fort nelson
# Processing Record 37 of Set 5 | tsalka
# Processing Record 38 of Set 5 | conceicao do araguaia
# Processing Record 39 of Set 5 | castro
# Processing Record 40 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 5 | laukaa
# Processing Record 42 of Set 5 | kabinda
# Processing Record 43 of Set 5 | hambantota
# Processing Record 44 of Set 5 | port lincoln
# Processing Record 45 of Set 5 | saint-ambroise
# Processing Record 46 of Set 5 | bouna
# Processing Record 47 of Set 5 | chokurdakh
# Processing Record 48 of Set 5 | port-gentil
# Processing Record 49 of Set 5 | cairns
# Processing Record 50 of Set 5 | kaitangata
# Processing Record 1 of Set 6 | mount pleasant
# Processing Record 2 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 6 | airai
# Processing Record 4 of Set 6 | tepalcatepec
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | lebu
# Processing Record 7 of Set 6 | faanui
# Processing Record 8 of Set 6 | nagato
# Processing Record 9 of Set 6 | araguatins
# City not found. Skipping...
# Processing Record 10 of Set 6 | ossora
# Processing Record 11 of Set 6 | quthing
# Processing Record 12 of Set 6 | havoysund
# Processing Record 13 of Set 6 | verkh-suetka
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | deputatskiy
# Processing Record 16 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 18 of Set 6 | asfi
# Processing Record 19 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 6 | coahuayana
# Processing Record 21 of Set 6 | yatou
# Processing Record 22 of Set 6 | buckingham
# Processing Record 23 of Set 6 | san andres
# Processing Record 24 of Set 6 | otradnoye
# Processing Record 25 of Set 6 | talara
# Processing Record 26 of Set 6 | lasa
# Processing Record 27 of Set 6 | saint-philippe
# Processing Record 28 of Set 6 | port stanley
# Processing Record 29 of Set 6 | dikson
# Processing Record 30 of Set 6 | kattivakkam
# Processing Record 31 of Set 6 | tiksi
# Processing Record 32 of Set 6 | brookings
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | ankpa
# Processing Record 35 of Set 6 | tessalit
# Processing Record 36 of Set 6 | shache
# Processing Record 37 of Set 6 | partenit
# Processing Record 38 of Set 6 | opatija
# Processing Record 39 of Set 6 | bathsheba
# Processing Record 40 of Set 6 | phalombe
# Processing Record 41 of Set 6 | mandera
# Processing Record 42 of Set 6 | itoman
# Processing Record 43 of Set 6 | kruisfontein
# Processing Record 44 of Set 6 | buraydah
# Processing Record 45 of Set 6 | sao jose da coroa grande
# Processing Record 46 of Set 6 | fartura
# Processing Record 47 of Set 6 | ponta do sol
# Processing Record 48 of Set 6 | mamaku
# Processing Record 49 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 6 | bonga
# Processing Record 1 of Set 7 | katherine
# Processing Record 2 of Set 7 | chara
# Processing Record 3 of Set 7 | pachelma
# Processing Record 4 of Set 7 | vila
# Processing Record 5 of Set 7 | whitecourt
# Processing Record 6 of Set 7 | san lorenzo
# Processing Record 7 of Set 7 | nishihara
# Processing Record 8 of Set 7 | hasaki
# Processing Record 9 of Set 7 | key west
# Processing Record 10 of Set 7 | mehamn
# Processing Record 11 of Set 7 | maldonado
# Processing Record 12 of Set 7 | aripuana
# Processing Record 13 of Set 7 | springdale
# Processing Record 14 of Set 7 | tutoia
# Processing Record 15 of Set 7 | mahanoro
# Processing Record 16 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 7 | plover
# Processing Record 18 of Set 7 | sao joao da barra
# Processing Record 19 of Set 7 | pochutla
# Processing Record 20 of Set 7 | muroto
# Processing Record 21 of Set 7 | barrancabermeja
# Processing Record 22 of Set 7 | aitolikon
# City not found. Skipping...
# Processing Record 23 of Set 7 | yarkovo
# Processing Record 24 of Set 7 | mecca
# Processing Record 25 of Set 7 | altamont
# Processing Record 26 of Set 7 | gizo
# Processing Record 27 of Set 7 | port hardy
# Processing Record 28 of Set 7 | gat
# Processing Record 29 of Set 7 | rafaela
# Processing Record 30 of Set 7 | candido mota
# Processing Record 31 of Set 7 | tomatlan
# Processing Record 32 of Set 7 | shiyan
# Processing Record 33 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 34 of Set 7 | sao filipe
# Processing Record 35 of Set 7 | columbia
# Processing Record 36 of Set 7 | cotonou
# Processing Record 37 of Set 7 | kodiak
# Processing Record 38 of Set 7 | acarau
# Processing Record 39 of Set 7 | islahiye
# Processing Record 40 of Set 7 | betafo
# Processing Record 41 of Set 7 | izberbash
# Processing Record 42 of Set 7 | balingasay
# Processing Record 43 of Set 7 | tilichiki
# Processing Record 44 of Set 7 | inhambane
# Processing Record 45 of Set 7 | coria
# Processing Record 46 of Set 7 | srednekolymsk
# Processing Record 47 of Set 7 | kamenka
# Processing Record 48 of Set 7 | saint-pierre
# Processing Record 49 of Set 7 | suntar
# Processing Record 50 of Set 7 | shellbrook
# Processing Record 1 of Set 8 | yarmouth
# Processing Record 2 of Set 8 | matamoros
# Processing Record 3 of Set 8 | makakilo city
# Processing Record 4 of Set 8 | valparaiso
# Processing Record 5 of Set 8 | queenstown
# Processing Record 6 of Set 8 | palana
# Processing Record 7 of Set 8 | abtenau
# Processing Record 8 of Set 8 | caravelas
# Processing Record 9 of Set 8 | vila franca do campo
# Processing Record 10 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 8 | esperance
# Processing Record 12 of Set 8 | ca mau
# Processing Record 13 of Set 8 | saint anthony
# Processing Record 14 of Set 8 | kurkent
# Processing Record 15 of Set 8 | chaozhou
# Processing Record 16 of Set 8 | le port
# Processing Record 17 of Set 8 | ulladulla
# Processing Record 18 of Set 8 | sidrolandia
# Processing Record 19 of Set 8 | manicore
# Processing Record 20 of Set 8 | revelstoke
# Processing Record 21 of Set 8 | gornopravdinsk
# Processing Record 22 of Set 8 | glubokoe
# City not found. Skipping...
# Processing Record 23 of Set 8 | qui nhon
# Processing Record 24 of Set 8 | xichang
# Processing Record 25 of Set 8 | biak
# Processing Record 26 of Set 8 | peachland
# Processing Record 27 of Set 8 | lewistown
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | torbay
# Processing Record 30 of Set 8 | guider
# Processing Record 31 of Set 8 | dawei
# Processing Record 32 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 33 of Set 8 | polyarnyy
# Processing Record 34 of Set 8 | grand bend
# Processing Record 35 of Set 8 | sechura
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | pecos
# Processing Record 38 of Set 8 | camopi
# Processing Record 39 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 40 of Set 8 | tasiilaq
# Processing Record 41 of Set 8 | odweyne
# Processing Record 42 of Set 8 | puerto colombia
# Processing Record 43 of Set 8 | moville
# Processing Record 44 of Set 8 | mayor pablo lagerenza
# Processing Record 45 of Set 8 | klaksvik
# Processing Record 46 of Set 8 | moose factory
# Processing Record 47 of Set 8 | uige
# Processing Record 48 of Set 8 | huilong
# Processing Record 49 of Set 8 | suslovo
# Processing Record 50 of Set 8 | kidal
# Processing Record 1 of Set 9 | alofi
# Processing Record 2 of Set 9 | chulumani
# Processing Record 3 of Set 9 | saldanha
# Processing Record 4 of Set 9 | kiama
# Processing Record 5 of Set 9 | kropotkin
# Processing Record 6 of Set 9 | nikolsk
# Processing Record 7 of Set 9 | la ronge
# Processing Record 8 of Set 9 | den helder
# Processing Record 9 of Set 9 | awjilah
# Processing Record 10 of Set 9 | belmonte
# Processing Record 11 of Set 9 | isangel
# Processing Record 12 of Set 9 | atasu
# Processing Record 13 of Set 9 | pimenta bueno
# Processing Record 14 of Set 9 | matara
# Processing Record 15 of Set 9 | balakhninskiy
# Processing Record 16 of Set 9 | camacha
# Processing Record 17 of Set 9 | dekar
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 9 | hovd
# Processing Record 21 of Set 9 | smithers
# Processing Record 22 of Set 9 | ronne
# Processing Record 23 of Set 9 | boa vista
# Processing Record 24 of Set 9 | mattoon
# Processing Record 25 of Set 9 | vallenar
# Processing Record 26 of Set 9 | ishigaki
# Processing Record 27 of Set 9 | grand gaube
# Processing Record 28 of Set 9 | san policarpo
# Processing Record 29 of Set 9 | tezu
# Processing Record 30 of Set 9 | vestmannaeyjar
# Processing Record 31 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 32 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | macheng
# Processing Record 34 of Set 9 | thohoyandou
# Processing Record 35 of Set 9 | kwinana
# Processing Record 36 of Set 9 | kathu
# Processing Record 37 of Set 9 | auki
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | cabo san lucas
# Processing Record 40 of Set 9 | azrow
# City not found. Skipping...
# Processing Record 41 of Set 9 | kavaratti
# Processing Record 42 of Set 9 | simoes
# Processing Record 43 of Set 9 | sasovo
# Processing Record 44 of Set 9 | ojinaga
# Processing Record 45 of Set 9 | liverpool
# Processing Record 46 of Set 9 | mtsensk
# Processing Record 47 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 9 | kachiry
# Processing Record 49 of Set 9 | marzuq
# Processing Record 50 of Set 9 | lavrentiya
# Processing Record 1 of Set 10 | miri
# Processing Record 2 of Set 10 | angoche
# Processing Record 3 of Set 10 | lingao
# Processing Record 4 of Set 10 | ambon
# Processing Record 5 of Set 10 | xuanzhou
# Processing Record 6 of Set 10 | bousso
# Processing Record 7 of Set 10 | antofagasta
# Processing Record 8 of Set 10 | xinzhou
# Processing Record 9 of Set 10 | argir
# Processing Record 10 of Set 10 | osimo
# Processing Record 11 of Set 10 | morondava
# Processing Record 12 of Set 10 | hobyo
# Processing Record 13 of Set 10 | nome
# Processing Record 14 of Set 10 | reconquista
# Processing Record 15 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 10 | ancud
# Processing Record 17 of Set 10 | saint-augustin
# Processing Record 18 of Set 10 | mathathane
# Processing Record 19 of Set 10 | oranjestad
# Processing Record 20 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | douglas
# Processing Record 23 of Set 10 | qorveh
# Processing Record 24 of Set 10 | iranshahr
# Processing Record 25 of Set 10 | show low
# Processing Record 26 of Set 10 | alyangula
# Processing Record 27 of Set 10 | taoudenni
# Processing Record 28 of Set 10 | lalibela
# Processing Record 29 of Set 10 | lavumisa
# Processing Record 30 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 31 of Set 10 | sri aman
# Processing Record 32 of Set 10 | vostok
# Processing Record 33 of Set 10 | kenai
# Processing Record 34 of Set 10 | siyabuswa
# Processing Record 35 of Set 10 | cabot
# Processing Record 36 of Set 10 | mezen
# Processing Record 37 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 10 | kaili
# Processing Record 39 of Set 10 | brasileia
# Processing Record 40 of Set 10 | morro bay
# Processing Record 41 of Set 10 | arman
# Processing Record 42 of Set 10 | kysyl-syr
# Processing Record 43 of Set 10 | toma
# Processing Record 44 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 45 of Set 10 | menongue
# Processing Record 46 of Set 10 | okakarara
# Processing Record 47 of Set 10 | gamba
# Processing Record 48 of Set 10 | ilo
# Processing Record 49 of Set 10 | touros
# Processing Record 50 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 2 of Set 11 | antalaha
# Processing Record 3 of Set 11 | ystad
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | nemuro
# Processing Record 6 of Set 11 | pomichna
# Processing Record 7 of Set 11 | finnsnes
# Processing Record 8 of Set 11 | mitsamiouli
# Processing Record 9 of Set 11 | san carlos
# Processing Record 10 of Set 11 | asbestovskiy
# Processing Record 11 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 11 | delvada
# Processing Record 14 of Set 11 | monrovia
# Processing Record 15 of Set 11 | kishtwar
# Processing Record 16 of Set 11 | maceio
# Processing Record 17 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 11 | bairiki
# Processing Record 19 of Set 11 | anadyr
# Processing Record 20 of Set 11 | tual
# Processing Record 21 of Set 11 | oyem
# Processing Record 22 of Set 11 | maneadero
# Processing Record 23 of Set 11 | anchorage
# Processing Record 24 of Set 11 | ekhabi
# Processing Record 25 of Set 11 | mackay
# Processing Record 26 of Set 11 | nanganga
# Processing Record 27 of Set 11 | moen
# Processing Record 28 of Set 11 | bjerkvik
# Processing Record 29 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 11 | sinjar
# Processing Record 31 of Set 11 | west wendover
# Processing Record 32 of Set 11 | christchurch
# Processing Record 33 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 34 of Set 11 | nabire
# Processing Record 35 of Set 11 | fairbanks
# Processing Record 36 of Set 11 | krasni okny
# Processing Record 37 of Set 11 | at-bashi
# Processing Record 38 of Set 11 | sistranda
# Processing Record 39 of Set 11 | semey
# Processing Record 40 of Set 11 | mount gambier
# Processing Record 41 of Set 11 | vlissingen
# Processing Record 42 of Set 11 | ipixuna
# Processing Record 43 of Set 11 | tambura
# Processing Record 44 of Set 11 | bodden town
# Processing Record 45 of Set 11 | okhotsk
# Processing Record 46 of Set 11 | reporoa
# Processing Record 47 of Set 11 | andenes
# Processing Record 48 of Set 11 | emerald
# Processing Record 49 of Set 11 | balkhash
# Processing Record 50 of Set 11 | medveditskiy
# Processing Record 1 of Set 12 | karlstad
# Processing Record 2 of Set 12 | nizhniy kuranakh
# Processing Record 3 of Set 12 | rexburg
# Processing Record 4 of Set 12 | rio grande
# Processing Record 5 of Set 12 | avera
# Processing Record 6 of Set 12 | saint-joseph
# Processing Record 7 of Set 12 | monte escobedo
# Processing Record 8 of Set 12 | te anau
# Processing Record 9 of Set 12 | coihaique
# Processing Record 10 of Set 12 | kahului
# Processing Record 11 of Set 12 | karaton
# Processing Record 12 of Set 12 | sapouy
# Processing Record 13 of Set 12 | hay river
# Processing Record 14 of Set 12 | puerto el triunfo
# Processing Record 15 of Set 12 | kelowna
# Processing Record 16 of Set 12 | acaponeta
# Processing Record 17 of Set 12 | aanekoski
# Processing Record 18 of Set 12 | roald
# Processing Record 19 of Set 12 | sao miguel do araguaia
# Processing Record 20 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 12 | sakakah
# Processing Record 22 of Set 12 | khanpur
# Processing Record 23 of Set 12 | rocha
# Processing Record 24 of Set 12 | thessalon
# Processing Record 25 of Set 12 | mongu
# Processing Record 26 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 27 of Set 12 | tanabe
# Processing Record 28 of Set 12 | faya
# Processing Record 29 of Set 12 | dzhebariki-khaya
# Processing Record 30 of Set 12 | poum
# Processing Record 31 of Set 12 | bacolod
# Processing Record 32 of Set 12 | malchevskaya
# Processing Record 33 of Set 12 | homer
# Processing Record 34 of Set 12 | tiarei
# Processing Record 35 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 36 of Set 12 | cutervo
# Processing Record 37 of Set 12 | anloga
# Processing Record 38 of Set 12 | ikom
# Processing Record 39 of Set 12 | los llanos de aridane
# Processing Record 40 of Set 12 | leningradskiy
# Processing Record 41 of Set 12 | sosnogorsk
# Processing Record 42 of Set 12 | matagami
# Processing Record 43 of Set 12 | quebrangulo
# Processing Record 44 of Set 12 | matto
# City not found. Skipping...
# Processing Record 45 of Set 12 | bima
# Processing Record 46 of Set 12 | ostersund
# Processing Record 47 of Set 12 | konin
# Processing Record 48 of Set 12 | talcahuano
# Processing Record 49 of Set 12 | meulaboh
# Processing Record 50 of Set 12 | namatanai
# Processing Record 1 of Set 13 | parabel
# Processing Record 2 of Set 13 | port-cartier
# Processing Record 3 of Set 13 | skjervoy
# Processing Record 4 of Set 13 | cody
# Processing Record 5 of Set 13 | porteirinha
# Processing Record 6 of Set 13 | neuquen
# Processing Record 7 of Set 13 | carnot
# Processing Record 8 of Set 13 | the valley
# Processing Record 9 of Set 13 | bexhill
# Processing Record 10 of Set 13 | puerto del rosario
# Processing Record 11 of Set 13 | betare oya
# Processing Record 12 of Set 13 | agadir
# Processing Record 13 of Set 13 | santa quiteria
# Processing Record 14 of Set 13 | chenzhou
# Processing Record 15 of Set 13 | zhangye
# Processing Record 16 of Set 13 | chapais
# Processing Record 17 of Set 13 | iquique
# Processing Record 18 of Set 13 | qasigiannguit
# Processing Record 19 of Set 13 | marabba
# Processing Record 20 of Set 13 | wamba
# Processing Record 21 of Set 13 | inta
# Processing Record 22 of Set 13 | albanel
# Processing Record 23 of Set 13 | mocuba
# Processing Record 24 of Set 13 | racconigi
# Processing Record 25 of Set 13 | myitkyina
# Processing Record 26 of Set 13 | gardner
# Processing Record 27 of Set 13 | avanigadda
# Processing Record 28 of Set 13 | banjar
# Processing Record 29 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 13 | oranjemund
# Processing Record 31 of Set 13 | pushkar
# Processing Record 32 of Set 13 | kailua
# Processing Record 33 of Set 13 | celestun
# Processing Record 34 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 13 | beloha
# Processing Record 36 of Set 13 | montrose
# Processing Record 37 of Set 13 | rajapur
# Processing Record 38 of Set 13 | walvis bay
# Processing Record 39 of Set 13 | mao
# Processing Record 40 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 13 | newry
# Processing Record 42 of Set 13 | marsa matruh
# Processing Record 43 of Set 13 | tuatapere
# Processing Record 44 of Set 13 | verkhnevilyuysk
# Processing Record 45 of Set 13 | price
# Processing Record 46 of Set 13 | salinopolis
# Processing Record 47 of Set 13 | tautira
# Processing Record 48 of Set 13 | pangnirtung
# Processing Record 49 of Set 13 | goderich
# Processing Record 50 of Set 13 | coquimbo
# Processing Record 1 of Set 14 | horasan
# Processing Record 2 of Set 14 | mulanje
# Processing Record 3 of Set 14 | makung
# City not found. Skipping...
# Processing Record 4 of Set 14 | sioux lookout
# Processing Record 5 of Set 14 | togul
# Processing Record 6 of Set 14 | yar-sale
# Processing Record 7 of Set 14 | kiunga
# Processing Record 8 of Set 14 | cascas
# Processing Record 9 of Set 14 | jiaocheng
# Processing Record 10 of Set 14 | emba
# Processing Record 11 of Set 14 | laguna
# Processing Record 12 of Set 14 | castro-urdiales
# Processing Record 13 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 14 | george town
# Processing Record 15 of Set 14 | port hedland
# Processing Record 16 of Set 14 | nantucket
# Processing Record 17 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 14 | khipro
# Processing Record 19 of Set 14 | mallama
# City not found. Skipping...
# Processing Record 20 of Set 14 | itirucu
# Processing Record 21 of Set 14 | tahoua
# Processing Record 22 of Set 14 | sur
# Processing Record 23 of Set 14 | archidona
# Processing Record 24 of Set 14 | kalamnuri
# Processing Record 25 of Set 14 | karpuninskiy
# City not found. Skipping...
# Processing Record 26 of Set 14 | vardo
# Processing Record 27 of Set 14 | forset
# City not found. Skipping...
# Processing Record 28 of Set 14 | northam
# Processing Record 29 of Set 14 | kangaatsiaq
# Processing Record 30 of Set 14 | seguela
# Processing Record 31 of Set 14 | soyo
# Processing Record 32 of Set 14 | kousseri
# Processing Record 33 of Set 14 | watrous
# Processing Record 34 of Set 14 | shingu
# Processing Record 35 of Set 14 | fallon
# Processing Record 36 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 14 | quzhou
# Processing Record 38 of Set 14 | rogun
# City not found. Skipping...
# Processing Record 39 of Set 14 | vagur
# Processing Record 40 of Set 14 | moshupa
# Processing Record 41 of Set 14 | mandan
# Processing Record 42 of Set 14 | hinatuan
# Processing Record 43 of Set 14 | malanje
# Processing Record 44 of Set 14 | sapa
# Processing Record 45 of Set 14 | ha tinh
# Processing Record 46 of Set 14 | tucuma
# Processing Record 47 of Set 14 | sultanpur
# Processing Record 48 of Set 14 | lithakia
# Processing Record 49 of Set 14 | malyye derbety
# Processing Record 50 of Set 14 | hearst
# Processing Record 1 of Set 15 | kumbo
# Processing Record 2 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 3 of Set 15 | wewak
# Processing Record 4 of Set 15 | port shepstone
# Processing Record 5 of Set 15 | namibe
# Processing Record 6 of Set 15 | andilamena
# Processing Record 7 of Set 15 | zalantun
# Processing Record 8 of Set 15 | havre-saint-pierre
# Processing Record 9 of Set 15 | dum duma
# Processing Record 10 of Set 15 | montague
# Processing Record 11 of Set 15 | mabaruma
# Processing Record 12 of Set 15 | nyirvasvari
# Processing Record 13 of Set 15 | filadelfia
# Processing Record 14 of Set 15 | kitimat
# Processing Record 15 of Set 15 | beyneu
# Processing Record 16 of Set 15 | dong hoi
# Processing Record 17 of Set 15 | saint-francois
# Processing Record 18 of Set 15 | mahon
# Processing Record 19 of Set 15 | parsabad
# Processing Record 20 of Set 15 | bijie
# Processing Record 21 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 15 | santa adelia
# Processing Record 23 of Set 15 | paamiut
# Processing Record 24 of Set 15 | hit
# Processing Record 25 of Set 15 | khani
# Processing Record 26 of Set 15 | newport
# Processing Record 27 of Set 15 | trinidad
# Processing Record 28 of Set 15 | yumen
# Processing Record 29 of Set 15 | orlik
# Processing Record 30 of Set 15 | estelle
# Processing Record 31 of Set 15 | zhuzhou
# Processing Record 32 of Set 15 | sabang
# Processing Record 33 of Set 15 | udachnyy
# Processing Record 34 of Set 15 | kendari
# Processing Record 35 of Set 15 | mercedes
# Processing Record 36 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 15 | san quintin
# Processing Record 38 of Set 15 | hede
# Processing Record 39 of Set 15 | champerico
# Processing Record 40 of Set 15 | san ignacio
# Processing Record 41 of Set 15 | krasnoselkup
# Processing Record 42 of Set 15 | saint-georges
# Processing Record 43 of Set 15 | tiznit
# Processing Record 44 of Set 15 | beringovskiy
# Processing Record 45 of Set 15 | bandar-e lengeh
# Processing Record 46 of Set 15 | binabalian
# Processing Record 47 of Set 15 | jumla
# Processing Record 48 of Set 15 | luzhou
# Processing Record 49 of Set 15 | kedgwick
# Processing Record 50 of Set 15 | ketchikan
# Processing Record 1 of Set 16 | kasongo
# Processing Record 2 of Set 16 | tuy hoa
# Processing Record 3 of Set 16 | strezhevoy
# Processing Record 4 of Set 16 | ust-nera
# Processing Record 5 of Set 16 | berlevag
# Processing Record 6 of Set 16 | corn island
# Processing Record 7 of Set 16 | barcelos
# Processing Record 8 of Set 16 | deder
# Processing Record 9 of Set 16 | voh
# Processing Record 10 of Set 16 | cape canaveral
# Processing Record 11 of Set 16 | kapustin yar-1
# City not found. Skipping...
# Processing Record 12 of Set 16 | umea
# Processing Record 13 of Set 16 | nizhniy chir
# Processing Record 14 of Set 16 | rio gallegos
# Processing Record 15 of Set 16 | catamarca
# Processing Record 16 of Set 16 | tarakan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Lae  -6.7221  146.9847     75.87        63         100        6.13
# 1      Rikitea -23.1203 -134.9692     77.90        70          69        3.15
# 2       Dingle  10.9995  122.6711     74.07        95         100        7.18
# 3       Sorong  -0.8833  131.2500     80.64        80          97        9.71
# 4        Pevek  69.7008  170.3133    -31.20       100         100        4.54
# 5  Saint-Louis  16.3333  -15.0000     80.24        12          99       10.09
# 6    Marrakesh  31.6315   -8.0083     53.67        76          20        8.05
# 7         Hilo  19.7297 -155.0900     82.13        76          40       12.66
# 8  Provideniya  64.3833 -173.3000    -12.89        58           0        8.95
# 9       Aykhal  66.0000  111.5000    -47.54       100          90        1.14
#
#   Country Current Description
# 0      PG     overcast clouds
# 1      PF       broken clouds
# 2      PH     overcast clouds
# 3      ID     overcast clouds
# 4      RU     overcast clouds
# 5      SN     overcast clouds
# 6      MA          few clouds
# 7      US    scattered clouds
# 8      RU           clear sky
# 9      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Lae      PG  -6.7221  146.9847     75.87        63         100
# 1      Rikitea      PF -23.1203 -134.9692     77.90        70          69
# 2       Dingle      PH  10.9995  122.6711     74.07        95         100
# 3       Sorong      ID  -0.8833  131.2500     80.64        80          97
# 4        Pevek      RU  69.7008  170.3133    -31.20       100         100
# 5  Saint-Louis      SN  16.3333  -15.0000     80.24        12          99
# 6    Marrakesh      MA  31.6315   -8.0083     53.67        76          20
# 7         Hilo      US  19.7297 -155.0900     82.13        76          40
# 8  Provideniya      RU  64.3833 -173.3000    -12.89        58           0
# 9       Aykhal      RU  66.0000  111.5000    -47.54       100          90
#
#    Wind Speed Current Description
# 0        6.13     overcast clouds
# 1        3.15       broken clouds
# 2        7.18     overcast clouds
# 3        9.71     overcast clouds
# 4        4.54     overcast clouds
# 5       10.09     overcast clouds
# 6        8.05          few clouds
# 7       12.66    scattered clouds
# 8        8.95           clear sky
# 9        1.14     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# %%
city_data_df.to_csv(output_data_file, index_label="City_ID")
